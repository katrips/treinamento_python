# %% [markdown]
# # 6. Exercícios

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 6.1 Leia o dataset titanic do seaborn em um df chamado "df_titanic"

# %%
df_titanic = sns.load_dataset("titanic")

# %%
# não execute essa linha
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #### 6.2 Defina o estilo do notebook como "whitegrid"

# %%
sns.set_style("whitegrid")

# %% [markdown]
# #### 6.3 Mímica

# %%
# não execute essa linha

# %% [markdown]
# #### 6.4 Mímica

# %%
# Não rode essa linha
# Out:
# (0.0, 500.0)

# %% [markdown]
# #### 6.5 Mímica

# %%
# Não rode

# %% [markdown]
# #### 6.6 Mímica

# %%
# Nope
# Out:
# <Axes: xlabel='class', ylabel='age'>
# C:\Users\rickk\anaconda3\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### 6.7 Mímica

# %%
# Nope
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #### 6.8 Mímica

# %%
# Non
# Out:
# <Axes: >

# %% [markdown]
# #### 6.9 Mímica

# %%
# Nope

# %% [markdown]
# # Nice!

# %% [markdown]
# <a><img src="https://media.tenor.com/CEfNKY-zkyQAAAAC/cheering-minions.gif" width = "800"/></a>
